# %%
import matplotlib.pyplot as plt
import numpy as np;
import scipy.optimize as opt;

# %%
xdata=[5,3.5,3,2]
ydata=[0.2,0.25,0.3,0.4]

# %%
def func(x, a, b, c):
     return a * np.exp(-b * x) + c

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(xdata,ydata)
for i,xy in enumerate(zip(xdata, ydata)):                                 
    # ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data', label='asd')
    ax.annotate(('t={}'.format(i)), xy=xy)

ax.set_title('Parameters for minimizing loss between noise and video')
ax.set_xlabel('Smoothing disk size')
ax.set_ylabel('Threshold')

# optimizedParameters, pcov = opt.curve_fit(func, xdata, ydata)

# # Use the optimized parameters to plot the best fit
# ax.plot(xdata, func(xdata, *optimizedParameters), label="fit")

# Show the graph
# plt.legend()
ax.grid()
plt.tight_layout()
plt.show()
