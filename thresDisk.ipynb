# %%
from src.distance_measures import analyse_video, analyse_image
from src.gaussian_noise import generate_noise
from src.preprocessing import process_image, process_video
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import label2rgb
from scipy.optimize import curve_fit

from skimage import morphology, filters
from skimage.morphology import label

# %%
size=400
im = np.random.normal(size=(size, size))

# %%
def disk_threshold_relation(disk_size,threshold):
    """Generates a list of random noise images"""   
    
    disk = morphology.disk(disk_size)
    imFilt = filters.median(im, disk)

    thresh = threshold if threshold != None else filters.threshold_otsu(imFilt)
    imThresh = imFilt > thresh
    # labels = label(imThresh)

    # return labels
    return imThresh


def model(thresh, disk):
    noise = generate_noise(size=size, threshold=thresh, disk_size=disk, amount=3)
    F, G = analyse_video(noise, L=50)
    return np.mean(F, axis=0)/np.mean(G, axis=0)

# %%
from tqdm import tqdm

def target_func(ref_disk_size, ref_threshold, test_disk_size, test_threshold):
    noise1 = disk_threshold_relation(ref_disk_size, ref_threshold)
    noise2 = disk_threshold_relation(test_disk_size, test_threshold)
    return np.count_nonzero(np.logical_not(noise1,noise2))

# %%
best=[10000,0,0]

ref_disk_size, ref_threshold = 1., -1.96
best_list = []
for q in tqdm(range(50)):
    range_disk=np.linspace(ref_disk_size+1,ref_disk_size*2,5)
    range_thr =np.linspace(ref_threshold+0.2, ref_threshold+0.4,100)
    for i in range_disk:
        for j in range_thr:
            val =target_func(ref_disk_size, ref_threshold,i,j)
            print(i,j)
            if val<best[0]:
                best =[val,i,j]
            print(val)
    best_list.append(best)
    ref_disk_size, ref_threshold = best[1],best[2]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2.0 -1.76
# 30
# 2.0 -1.757979797979798
# 30
# 2.0 -1.755959595959596
# 30
# 2.0 -1.753939393939394
# 30
# 2.0 -1.7519191919191919
# 30
# 2.0 -1.7498989898989898
# 30
# 2.0 -1.7478787878787878
# 30
# 2.0 -1.7458585858585858
# 30
# 2.0 -1.7438383838383837
# 30
# 2.0 -1.741818181818182
# 30
# 2.0 -1.73979797979798
# 30
# 2.0 -1.7377777777777779
# 30
# 2.0 -1.7357575757575758
# 30
# 2.0 -1.7337373737373738
# 30
# 2.0 -1.7317171717171718
# 30
# 2.0 -1.7296969696969697
# 30
# 2.0 -1.7276767676767677
# 30
# 2.0 -1.7256565656565657
# 30
# 2.0 -1.7236363636363636
# 30
# 2.0 -1.7216161616161616
# 30
# 2.0 -1.7195959595959596
# 30
# 2.0 -1.7175757575757575
# 30
# 2.0 -1.7155555555555555
# 30
# 2.0 -1.7135353535353535
# 30
# 2.0 -1.7115151515151514
# 30
# 2.0 -1.7094949494949496
# 30
# 2.0 -1.7074747474747476
# 30
# 2.0 -1.7054545454545456
# 30
# 2.0 -1.7034343434343435
# 30
# 2.0 -1.7014141414141415
# 30
# 2.0 -1.6993939393939395
# 30
# 2.0 -1.6973737373737374
# 30
# 2.0 -1.6953535353535354
# 30
# 2.0 -1.6933333333333334
# 30
# 2.0 -1.6913131313131313
# 30
# 2.0 -1.6892929292929293
# 30
# 2.0 -1.6872727272727273
# 30
# 2.0 -1.6852525252525252
# 30
# 2.0 -1.6832323232323232
# 30
# 2.0 -1.6812121212121212
# 30
# 2.0 -1.6791919191919191
# 30
# 2.0 -1.677171717171717
# 30
# 2.0 -1.6751515151515153
# 30
# 2.0 -1.6731313131313132
# 30
# 2.0 -1.6711111111111112
# 30
# 2.0 -1.6690909090909092
# 30
# 2.0 -1.6670707070707071
# 30
# 2.0 -1.6650505050505051
# 30
# 2.0 -1.663030303030303
# 30
# 2.0 -1.661010101010101
# 30
# 2.0 -1.658989898989899
# 30
# 2.0 -1.656969696969697
# 30
# 2.0 -1.654949494949495
# 30
# 2.0 -1.652929292929293
# 30
# 2.0 -1.6509090909090909
# 30
# 2.0 -1.6488888888888888
# 30
# 2.0 -1.6468686868686868
# 30
# 2.0 -1.6448484848484848
# 30
# 2.0 -1.6428282828282827
# 30
# 2.0 -1.640808080808081
# 30
# 2.0 -1.638787878787879
# 30
# 2.0 -1.6367676767676769
# 30
# 2.0 -1.6347474747474748
# 30
# 2.0 -1.6327272727272728
# 30
# 2.0 -1.6307070707070708
# 30
# 2.0 -1.6286868686868687
# 30
# 2.0 -1.6266666666666667
# 30
# 2.0 -1.6246464646464647
# 30
# 2.0 -1.6226262626262626
# 30
# 2.0 -1.6206060606060606
# 30
# 2.0 -1.6185858585858586
# 30
# 2.0 -1.6165656565656565
# 30
# 2.0 -1.6145454545454545
# 30
# 2.0 -1.6125252525252525
# 30
# 2.0 -1.6105050505050507
# 30
# 2.0 -1.6084848484848484
# 30
# 2.0 -1.6064646464646466
# 30
# 2.0 -1.6044444444444446
# 30
# 2.0 -1.6024242424242425
# 30
# 2.0 -1.6004040404040405
# 30
# 2.0 -1.5983838383838385
# 30
# 2.0 -1.5963636363636364
# 30
# 2.0 -1.5943434343434344
# 30
# 2.0 -1.5923232323232324
# 30
# 2.0 -1.5903030303030303
# 30
# 2.0 -1.5882828282828283
# 30
# 2.0 -1.5862626262626263
# 30
# 2.0 -1.5842424242424242
# 30
# 2.0 -1.5822222222222222
# 30
# 2.0 -1.5802020202020202
# 30
# 2.0 -1.5781818181818181
# 30
# 2.0 -1.5761616161616163
# 30
# 2.0 -1.5741414141414143
# 30
# 2.0 -1.5721212121212123
# 30
# 2.0 -1.5701010101010102
# 30
# 2.0 -1.5680808080808082
# 30
# 2.0 -1.5660606060606062
# 30
# 2.0 -1.5640404040404041
# 30
# 2.0 -1.562020202020202
# 30
# 2.0 -1.56
# 30
# 2.0 -1.76
# 30
# 2.0 -1.757979797979798
# 30
# 2.0 -1.755959595959596
# 30
# 2.0 -1.753939393939394
# 30
# 2.0 -1.7519191919191919
# 30
# 2.0 -1.7498989898989898
# 30
# 2.0 -1.7478787878787878
# 30
# 2.0 -1.7458585858585858
# 30
# 2.0 -1.7438383838383837
# 30
# 2.0 -1.741818181818182
# 30
# 2.0 -1.73979797979798
# 30
# 2.0 -1.7377777777777779
# 30
# 2.0 -1.7357575757575758
# 30
# 2.0 -1.7337373737373738
# 30
# 2.0 -1.7317171717171718
# 30
# 2.0 -1.7296969696969697
# 30
# 2.0 -1.7276767676767677
# 30
# 2.0 -1.7256565656565657
# 30
# 2.0 -1.7236363636363636
# 30
# 2.0 -1.7216161616161616
# 30
# 2.0 -1.7195959595959596
# 30
# 2.0 -1.7175757575757575
# 30
# 2.0 -1.7155555555555555
# 30
# 2.0 -1.7135353535353535
# 30
# 2.0 -1.7115151515151514
# 30
# 2.0 -1.7094949494949496
# 30
# 2.0 -1.7074747474747476
# 30
# 2.0 -1.7054545454545456
# 30
# 2.0 -1.7034343434343435
# 30
# 2.0 -1.7014141414141415
# 30
# 2.0 -1.6993939393939395
# 30
# 2.0 -1.6973737373737374
# 30
# 2.0 -1.6953535353535354
# 30
# 2.0 -1.6933333333333334
# 30
# 2.0 -1.6913131313131313
# 30
# 2.0 -1.6892929292929293
# 30
# 2.0 -1.6872727272727273
# 30
# 2.0 -1.6852525252525252
# 30
# 2.0 -1.6832323232323232
# 30
# 2.0 -1.6812121212121212
# 30
# 2.0 -1.6791919191919191
# 30
# 2.0 -1.677171717171717
# 30
# 2.0 -1.6751515151515153
# 30
# 2.0 -1.6731313131313132
# 30
# 2.0 -1.6711111111111112
# 30
# 2.0 -1.6690909090909092
# 30
# 2.0 -1.6670707070707071
# 30
# 2.0 -1.6650505050505051
# 30
# 2.0 -1.663030303030303
# 30
# 2.0 -1.661010101010101
# 30
# 2.0 -1.658989898989899
# 30
# 2.0 -1.656969696969697
# 30
# 2.0 -1.654949494949495
# 30
# 2.0 -1.652929292929293
# 30
# 2.0 -1.6509090909090909
# 30
# 2.0 -1.6488888888888888
# 30
# 2.0 -1.6468686868686868
# 30
# 2.0 -1.6448484848484848
# 30
# 2.0 -1.6428282828282827
# 30
# 2.0 -1.640808080808081
# 30
# 2.0 -1.638787878787879
# 30
# 2.0 -1.6367676767676769
# 30
# 2.0 -1.6347474747474748
# 30
# 2.0 -1.6327272727272728
# 30
# 2.0 -1.6307070707070708
# 30
# 2.0 -1.6286868686868687
# 30
# 2.0 -1.6266666666666667
# 30
# 2.0 -1.6246464646464647
# 30
# 2.0 -1.6226262626262626
# 30
# 2.0 -1.6206060606060606
# 30
# 2.0 -1.6185858585858586
# 30
# 2.0 -1.6165656565656565
# 30
# 2.0 -1.6145454545454545
# 30
# 2.0 -1.6125252525252525
# 30
# 2.0 -1.6105050505050507
# 30
# 2.0 -1.6084848484848484
# 30
# 2.0 -1.6064646464646466
# 30
# 2.0 -1.6044444444444446
# 30
# 2.0 -1.6024242424242425
# 30
# 2.0 -1.6004040404040405
# 30
# 2.0 -1.5983838383838385
# 30
# 2.0 -1.5963636363636364
# 30
# 2.0 -1.5943434343434344
# 30
# 2.0 -1.5923232323232324
# 30
# 2.0 -1.5903030303030303
# 30
# 2.0 -1.5882828282828283
# 30
# 2.0 -1.5862626262626263
# 30
# 2.0 -1.5842424242424242
# 30
# 2.0 -1.5822222222222222
# 30
# 2.0 -1.5802020202020202
# 30
# 2.0 -1.5781818181818181
# 30
# 2.0 -1.5761616161616163
# 30
# 2.0 -1.5741414141414143
# 30
# 2.0 -1.5721212121212123
# 30
# 2.0 -1.5701010101010102
# 30
# 2.0 -1.5680808080808082
# 30
# 2.0 -1.5660606060606062
# 30
# 2.0 -1.5640404040404041
# 30
# 2.0 -1.562020202020202
# 30
# 2.0 -1.56
# 30
# 2.0 -1.76
# 30
# 2.0 -1.757979797979798
# 30
# 2.0 -1.755959595959596
# 30
# 2.0 -1.753939393939394
# 30
# 2.0 -1.7519191919191919
# 30
# 2.0 -1.7498989898989898
# 30
# 2.0 -1.7478787878787878
# 30
# 2.0 -1.7458585858585858
# 30
# 2.0 -1.7438383838383837
# 30
# 2.0 -1.741818181818182
# 30
# 2.0 -1.73979797979798
# 30
# 2.0 -1.7377777777777779
# 30
# 2.0 -1.7357575757575758
# 30
# 2.0 -1.7337373737373738
# 30
# 2.0 -1.7317171717171718
# 30
# 2.0 -1.7296969696969697
# 30
# 2.0 -1.7276767676767677
# 30
# 2.0 -1.7256565656565657
# 30
# 2.0 -1.7236363636363636
# 30
# 2.0 -1.7216161616161616
# 30
# 2.0 -1.7195959595959596
# 30
# 2.0 -1.7175757575757575
# 30
# 2.0 -1.7155555555555555
# 30
# 2.0 -1.7135353535353535
# 30
# 2.0 -1.7115151515151514
# 30
# 2.0 -1.7094949494949496
# 30
# 2.0 -1.7074747474747476
# 30
# 2.0 -1.7054545454545456
# 30
# 2.0 -1.7034343434343435
# 30
# 2.0 -1.7014141414141415
# 30
# 2.0 -1.6993939393939395
# 30
# 2.0 -1.6973737373737374
# 30
# 2.0 -1.6953535353535354
# 30
# 2.0 -1.6933333333333334
# 30
# 2.0 -1.6913131313131313
# 30
# 2.0 -1.6892929292929293
# 30
# 2.0 -1.6872727272727273
# 30
# 2.0 -1.6852525252525252
# 30
# 2.0 -1.6832323232323232
# 30
# 2.0 -1.6812121212121212
# 30
# 2.0 -1.6791919191919191
# 30
# 2.0 -1.677171717171717
# 30
# 2.0 -1.6751515151515153
# 30
# 2.0 -1.6731313131313132
# 30
# 2.0 -1.6711111111111112
# 30
# 2.0 -1.6690909090909092
# 30
# 2.0 -1.6670707070707071
# 30
# 2.0 -1.6650505050505051
# 30
# 2.0 -1.663030303030303
# 30
# 2.0 -1.661010101010101
# 30
# 2.0 -1.658989898989899
# 30
# 2.0 -1.656969696969697
# 30
# 2.0 -1.654949494949495
# 30
# 2.0 -1.652929292929293
# 30
# 2.0 -1.6509090909090909
# 30
# 2.0 -1.6488888888888888
# 30
# 2.0 -1.6468686868686868
# 30
# 2.0 -1.6448484848484848
# 30
# 2.0 -1.6428282828282827
# 30
# 2.0 -1.640808080808081
# 30
# 2.0 -1.638787878787879
# 30
# 2.0 -1.6367676767676769
# 30
# 2.0 -1.6347474747474748
# 30
# 2.0 -1.6327272727272728
# 30
# 2.0 -1.6307070707070708
# 30
# 2.0 -1.6286868686868687
# 30
# 2.0 -1.6266666666666667
# 30
# 2.0 -1.6246464646464647
# 30
# 2.0 -1.6226262626262626
# 30
# 2.0 -1.6206060606060606
# 30
# 2.0 -1.6185858585858586
# 30
# 2.0 -1.6165656565656565
# 30
# 2.0 -1.6145454545454545
# 30
# 2.0 -1.6125252525252525
# 30
# 2.0 -1.6105050505050507
# 30
# 2.0 -1.6084848484848484
# 30
# 2.0 -1.6064646464646466
# 30
# 2.0 -1.6044444444444446
# 30
# 2.0 -1.6024242424242425
# 30
# 2.0 -1.6004040404040405
# 30
# 2.0 -1.5983838383838385
# 30
# 2.0 -1.5963636363636364
# 30
# 2.0 -1.5943434343434344
# 30
# 2.0 -1.5923232323232324
# 30
# 2.0 -1.5903030303030303
# 30
# 2.0 -1.5882828282828283
# 30
# 2.0 -1.5862626262626263
# 30
# 2.0 -1.5842424242424242
# 30
# 2.0 -1.5822222222222222
# 30
# 2.0 -1.5802020202020202
# 30
# 2.0 -1.5781818181818181
# 30
# 2.0 -1.5761616161616163
# 30
# 2.0 -1.5741414141414143
# 30
# 2.0 -1.5721212121212123
# 30
# 2.0 -1.5701010101010102
# 30
# 2.0 -1.5680808080808082
# 30
# 2.0 -1.5660606060606062
# 30
# 2.0 -1.5640404040404041
# 30
# 2.0 -1.562020202020202
# 30
# 2.0 -1.56
# 30
# 2.0 -1.76
# 30
# 2.0 -1.757979797979798
# 30
# 2.0 -1.755959595959596
# 30
# 2.0 -1.753939393939394
# 30
# 2.0 -1.7519191919191919
# 30
# 2.0 -1.7498989898989898
# 30
# 2.0 -1.7478787878787878
# 30
# 2.0 -1.7458585858585858
# 30
# 2.0 -1.7438383838383837
# 30
# 2.0 -1.741818181818182
# 30
# 2.0 -1.73979797979798
# 30
# 2.0 -1.7377777777777779
# 30
# 2.0 -1.7357575757575758
# 30
# 2.0 -1.7337373737373738
# 30
# 2.0 -1.7317171717171718
# 30
# 2.0 -1.7296969696969697
# 30
# 2.0 -1.7276767676767677
# 30
# 2.0 -1.7256565656565657
# 30
# 2.0 -1.7236363636363636
# 30
# 2.0 -1.7216161616161616
# 30
# 2.0 -1.7195959595959596
# 30
# 2.0 -1.7175757575757575
# 30
# 2.0 -1.7155555555555555
# 30
# 2.0 -1.7135353535353535
# 30
# 2.0 -1.7115151515151514
# 30
# 2.0 -1.7094949494949496
# 30
# 2.0 -1.7074747474747476
# 30
# 2.0 -1.7054545454545456
# 30
# 2.0 -1.7034343434343435
# 30
# 2.0 -1.7014141414141415
# 30
# 2.0 -1.6993939393939395
# 30
# 2.0 -1.6973737373737374
# 30
# 2.0 -1.6953535353535354
# 30
# 2.0 -1.6933333333333334
# 30
# 2.0 -1.6913131313131313
# 30
# 2.0 -1.6892929292929293
# 30
# 2.0 -1.6872727272727273
# 30
# 2.0 -1.6852525252525252
# 30
# 2.0 -1.6832323232323232
# 30
# 2.0 -1.6812121212121212
# 30
# 2.0 -1.6791919191919191
# 30
# 2.0 -1.677171717171717
# 30
# 2.0 -1.6751515151515153
# 30
# 2.0 -1.6731313131313132
# 30
# 2.0 -1.6711111111111112
# 30
# 2.0 -1.6690909090909092
# 30
# 2.0 -1.6670707070707071
# 30
# 2.0 -1.6650505050505051
# 30
# 2.0 -1.663030303030303
# 30
# 2.0 -1.661010101010101
# 30
# 2.0 -1.658989898989899
# 30
# 2.0 -1.656969696969697
# 30
# 2.0 -1.654949494949495
# 30
# 2.0 -1.652929292929293
# 30
# 2.0 -1.6509090909090909
# 30
# 2.0 -1.6488888888888888
# 30
# 2.0 -1.6468686868686868
# 30
# 2.0 -1.6448484848484848
# 30
# 2.0 -1.6428282828282827
# 30
# 2.0 -1.640808080808081
# 30
# 2.0 -1.638787878787879
# 30
# 2.0 -1.6367676767676769
# 30
# 2.0 -1.6347474747474748
# 30
# 2.0 -1.6327272727272728
# 30
# 2.0 -1.6307070707070708
# 30
# 2.0 -1.6286868686868687
# 30
# 2.0 -1.6266666666666667
# 30
# 2.0 -1.6246464646464647
# 30
# 2.0 -1.6226262626262626
# 30
# 2.0 -1.6206060606060606
# 30
# 2.0 -1.6185858585858586
# 30
# 2.0 -1.6165656565656565
# 30
# 2.0 -1.6145454545454545
# 30
# 2.0 -1.6125252525252525
# 30
# 2.0 -1.6105050505050507
# 30
# 2.0 -1.6084848484848484
# 30
# 2.0 -1.6064646464646466
# 30
# 2.0 -1.6044444444444446
# 30
# 2.0 -1.6024242424242425
# 30
# 2.0 -1.6004040404040405
# 30
# 2.0 -1.5983838383838385
# 30
# 2.0 -1.5963636363636364
# 30
# 2.0 -1.5943434343434344
# 30
# 2.0 -1.5923232323232324
# 30
# 2.0 -1.5903030303030303
# 30
# 2.0 -1.5882828282828283
# 30
# 2.0 -1.5862626262626263
# 30
# 2.0 -1.5842424242424242
# 30
# 2.0 -1.5822222222222222
# 30
# 2.0 -1.5802020202020202
# 30
# 2.0 -1.5781818181818181
# 30
# 2.0 -1.5761616161616163
# 30
# 2.0 -1.5741414141414143
# 30
# 2.0 -1.5721212121212123
# 30
# 2.0 -1.5701010101010102
# 30
# 2.0 -1.5680808080808082
# 30
# 2.0 -1.5660606060606062
# 30
# 2.0 -1.5640404040404041
# 30
# 2.0 -1.562020202020202
# 30
# 2.0 -1.56
# 30
# 2.0 -1.76
# 30
# 2.0 -1.757979797979798
# 30
# 2.0 -1.755959595959596
# 30
# 2.0 -1.753939393939394
# 30
# 2.0 -1.7519191919191919
# 30
# 2.0 -1.7498989898989898
# 30
# 2.0 -1.7478787878787878
# 30
# 2.0 -1.7458585858585858
# 30
# 2.0 -1.7438383838383837
# 30
# 2.0 -1.741818181818182
# 30
# 2.0 -1.73979797979798
# 30
# 2.0 -1.7377777777777779
# 30
# 2.0 -1.7357575757575758
# 30
# 2.0 -1.7337373737373738
# 30
# 2.0 -1.7317171717171718
# 30
# 2.0 -1.7296969696969697
# 30
# 2.0 -1.7276767676767677
# 30
# 2.0 -1.7256565656565657
# 30
# 2.0 -1.7236363636363636
# 30
# 2.0 -1.7216161616161616
# 30
# 2.0 -1.7195959595959596
# 30
# 2.0 -1.7175757575757575
# 30
# 2.0 -1.7155555555555555
# 30
# 2.0 -1.7135353535353535
# 30
# 2.0 -1.7115151515151514
# 30
# 2.0 -1.7094949494949496
# 30
# 2.0 -1.7074747474747476
# 30
# 2.0 -1.7054545454545456
# 30
# 2.0 -1.7034343434343435
# 30
# 2.0 -1.7014141414141415
# 30
# 2.0 -1.6993939393939395
# 30
# 2.0 -1.6973737373737374
# 30
# 2.0 -1.6953535353535354
# 30
# 2.0 -1.6933333333333334
# 30
# 2.0 -1.6913131313131313
# 30
# 2.0 -1.6892929292929293
# 30
# 2.0 -1.6872727272727273
# 30
# 2.0 -1.6852525252525252
# 30
# 2.0 -1.6832323232323232
# 30
# 2.0 -1.6812121212121212
# 30
# 2.0 -1.6791919191919191
# 30
# 2.0 -1.677171717171717
# 30
# 2.0 -1.6751515151515153
# 30
# 2.0 -1.6731313131313132
# 30
# 2.0 -1.6711111111111112
# 30
# 2.0 -1.6690909090909092
# 30
# 2.0 -1.6670707070707071
# 30
# 2.0 -1.6650505050505051
# 30
# 2.0 -1.663030303030303
# 30
# 2.0 -1.661010101010101
# 30
# 2.0 -1.658989898989899
# 30
# 2.0 -1.656969696969697
# 30
# 2.0 -1.654949494949495
# 30
# 2.0 -1.652929292929293
# 30
# 2.0 -1.6509090909090909
# 30
# 2.0 -1.6488888888888888
# 30
# 2.0 -1.6468686868686868
# 30
# 2.0 -1.6448484848484848
# 30
# 2.0 -1.6428282828282827
# 30
# 2.0 -1.640808080808081
# 30
# 2.0 -1.638787878787879
# 30
# 2.0 -1.6367676767676769
# 30
# 2.0 -1.6347474747474748
# 30
# 2.0 -1.6327272727272728
# 30
# 2.0 -1.6307070707070708
# 30
# 2.0 -1.6286868686868687
# 30
# 2.0 -1.6266666666666667
# 30
# 2.0 -1.6246464646464647
# 30
# 2.0 -1.6226262626262626
# 30
# 2.0 -1.6206060606060606
# 30
# 2.0 -1.6185858585858586
# 30
# 2.0 -1.6165656565656565
# 30
# 2.0 -1.6145454545454545
# 30
# 2.0 -1.6125252525252525
# 30
# 2.0 -1.6105050505050507
# 30
# 2.0 -1.6084848484848484
# 30
# 2.0 -1.6064646464646466
# 30
# 2.0 -1.6044444444444446
# 30
# 2.0 -1.6024242424242425
# 30
# 2.0 -1.6004040404040405
# 30
# 2.0 -1.5983838383838385
# 30
# 2.0 -1.5963636363636364
# 30
# 2.0 -1.5943434343434344
# 30
# 2.0 -1.5923232323232324
# 30
# 2.0 -1.5903030303030303
# 30
# 2.0 -1.5882828282828283
# 30
# 2.0 -1.5862626262626263
# 30
# 2.0 -1.5842424242424242
# 30
# 2.0 -1.5822222222222222
# 30
# 2.0 -1.5802020202020202
# 30
# 2.0 -1.5781818181818181
# 30
# 2.0 -1.5761616161616163
# 30
# 2.0 -1.5741414141414143
# 30
# 2.0 -1.5721212121212123
# 30
# 2.0 -1.5701010101010102
# 30
# 2.0 -1.5680808080808082
# 30
# 2.0 -1.5660606060606062
# 30
#   2%|▏         | 1/50 [00:19<15:52, 19.44s/it]
# 2.0 -1.5640404040404041
# 30
# 2.0 -1.562020202020202
# 30
# 2.0 -1.56
# 30
# 3.0 -1.56
# 0
# 3.0 -1.557979797979798
# 0
# 3.0 -1.555959595959596
# 0
# 3.0 -1.553939393939394
# 0
# 3.0 -1.551919191919192
# 0
# 3.0 -1.5498989898989899
# 0
# 3.0 -1.5478787878787879
# 0
# 3.0 -1.5458585858585858
# 0
# 3.0 -1.5438383838383838
# 0
# 3.0 -1.5418181818181818
/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-935a0c8e6259> in <module>
#       8     for i in range_disk:
#       9         for j in range_thr:
# ---> 10             val =target_func(ref_disk_size, ref_threshold,i,j)
#      11             print(i,j)
#      12             if val<best[0]:
#
# <ipython-input-30-dec6bbf971d0> in target_func(ref_disk_size, ref_threshold, test_disk_size, test_threshold)
#       3 def target_func(ref_disk_size, ref_threshold, test_disk_size, test_threshold):
#       4     noise1 = disk_threshold_relation(ref_disk_size, ref_threshold)
# ----> 5     noise2 = disk_threshold_relation(test_disk_size, test_threshold)
#       6     return np.count_nonzero(np.logical_not(noise1,noise2))
#
# <ipython-input-29-8b7c2617f3b9> in disk_threshold_relation(disk_size, threshold)
#       3
#       4     disk = morphology.disk(disk_size)
# ----> 5     imFilt = filters.median(im, disk)
#       6
#       7     thresh = threshold if threshold != None else filters.threshold_otsu(imFilt)
#
# /opt/anaconda3/lib/python3.7/site-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     280
#     281             # Call the function with the fixed arguments
# --> 282             return func(*args, **kwargs)
#     283
#     284         if func.__doc__ is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/skimage/filters/_median.py in median(image, footprint, out, mode, cval, behavior)
#      79         footprint = ndi.generate_binary_structure(image.ndim, image.ndim)
#      80     return ndi.median_filter(image, footprint=footprint, output=out, mode=mode,
# ---> 81                              cval=cval)
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/ndimage/filters.py in median_filter(input, size, footprint, output, mode, cval, origin)
#    1394     """
#    1395     return _rank_filter(input, 0, size, footprint, output, mode, cval,
# -> 1396                         origin, 'median')
#    1397
#    1398
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/ndimage/filters.py in _rank_filter(input, rank, size, footprint, output, mode, cval, origin, operation)
#    1301         mode = _ni_support._extend_mode_to_code(mode)
#    1302         _nd_image.rank_filter(input, rank, footprint, output, mode, cval,
# -> 1303                               origins)
#    1304         if temp_needed:
#    1305             temp[...] = output
#
# KeyboardInterrupt:

# %%
print(target_func(2.,0.2,2.1,0.45))
# Out:
# [[ 0.33581807  0.33581807  0.33581807 ... -0.72331286 -1.1015757
#   -0.61654067]
#  [ 0.33581807 -0.17616393 -0.00851172 ... -0.72331286 -0.61654067
#   -0.61654067]
#  [ 0.32571964 -0.32478237  0.11727859 ...  0.00189848 -0.09278281
#    0.18876911]
#  ...
#  [ 0.21772212  0.21120045  0.35103606 ...  0.26126835  0.1483118
#    0.1483118 ]
#  [ 0.21772212 -0.49337104 -0.49337104 ...  0.1483118   0.1483118
#    0.1483118 ]
#  [ 0.73610273 -0.94431885 -0.49337104 ...  0.71431072  0.71431072
#    0.95340475]]
# [[ 0.33581807  0.33581807  0.33581807 ... -0.72331286 -1.32521911
#   -1.32521911]
#  [ 0.33581807  0.33581807  0.33581807 ... -0.20699295 -0.72331286
#   -1.1015757 ]
#  [ 0.33581807  0.32571964 -0.17616393 ...  0.14264712 -0.72331286
#   -0.61654067]
#  ...
#  [ 0.2574518   0.21772212  0.21120045 ...  0.66880677  0.26126835
#   -0.12750171]
#  [ 0.21772212  0.21120045  0.21120045 ...  0.26126835  0.49564788
#    0.1483118 ]
#  [ 0.73610273  0.69468957 -0.49337104 ...  0.26126835  0.26126835
#    0.1483118 ]]
# 0

# %%
print(best_list)
